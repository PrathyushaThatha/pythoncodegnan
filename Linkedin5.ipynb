# %%
n="FullName:Prathyusha Thatha"
a="Headline:python full stack developer trainee |B.tech graduate|passionate about software"
b="Email:prathyushathatha1@gmail.com"
c="About:developer"
d="Experience:no"
e="companyname:codegnan"
f="role:trainee"
g=year:june2026
print(n)
# Out:
# FullName:Prathyusha Thatha
