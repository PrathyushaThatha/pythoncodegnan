# %% [markdown]
#  set charateristics

# %%
#set unodered collection
#set return unique elements
s={1,2,3,2,3,'hi','a',2.02,(10,20,30)}
print(s)
#print(s[0])/set does not supports indexing
#list cannot be used as set elements
s={1,2,[3,2,3],'hi','a',2.02,(10,20,30)}
print(s)
# Out:
# {'hi', 1, 2, 3, 'a', 2.02, (10, 20, 30)}

# %%
print({10,6,3,5})
print(
