# %%
#integer to float,boolean,string
num=10
print(float(num))
print(bool(num))
print(str(num))
print(complex(num))
# Out:
# 10.0
# True
# 10
# (10+0j)

# %%
#float to int,booland string
val=10.2556
num=int(val)
print(type(num),num)
print(bool(val))
str_val=str(val)
print(type(str_val),str_val)
print(str_val[:4])
print(str_val[1],str_val[-1])

# %%
val=102.25545521
strval=str(val)
ind=strval.find

# %%
b=True
print(int(b))
print(int(float(s))

# %%
#list to str,tuple,set
#tuple to str,lst,set
#set to str,lst,tuple
#dict to str,lst,set,tuple
val=[1,2,3,4]
num=str(val)
print(type(num),num)
print(bool(val))
t_val=tuple(val)
print(type(t_val),t_val)
print(t_val[:4])
print(t_val[1],t_val[-1])
# Out:
# <class 'str'> [1, 2, 3, 4]
# True
# <class 'str'> [1, 2, 3, 4]
# [1,
# 1 ]

# %%
val=(1,2,3,4)
num=str(val)
print(type(num),num)
print(bool(val))
str_val=str(val)
print(type(str_val),str_val)
print(str_val[:4])
print(str_val[1],str_val[-1])
# Out:
# <class 'str'> (1, 2, 3, 4)
# True
# <class 'str'> (1, 2, 3, 4)
# (1,
# 1 )

# %%
#list to dictionary conversion
l=[('a',1),('b',2)]
print(dict(l))
# Out:
# {'a': 1, 'b': 2}
