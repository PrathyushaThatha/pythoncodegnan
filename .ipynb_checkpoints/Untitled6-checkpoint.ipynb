# %%
#22/06/2026
u=int(input())
age=int(input())
if age>60 and age==senior:
    print(age)
if (u>0 and u<=100):
    t=u*1.5
    print(t)
elif (u>101 and u<=200):
    t=u*2.5
    print(t)
elif (u>201 and u<=500):
    t=u*4
    print(t)
else:
    t=u*6
    print(t)
if(age):
    bill=t*(10/100)-t
    print(bill)
else:
    print(t)
# Out:
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:4: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
