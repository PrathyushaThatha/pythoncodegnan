# %%
# check weather the number is+ve or -ve or zero
num=int(input())
if num>0:
    print(f'{num} is +ve')
elif num <0:
    print(f'{num} is -ve')
else:
    print(f'{num} is zero')
# Out:
#  9
# 9 is +ve

# %%
#divisible by 3-fizz
#divisible by 5-buzz
#both-fizzbuzz
num=int(input())
if num%3==0:
    print(f'{num} is fizz')
elif num%5==0:
    print(f'{num} is buzz')
elif num%3==0 and num%5==0:
    print(f'{num} is fizzbuzz')
else:
    print(invalid)
# Out:
#  15
# 15 is fizz

# %%
num=int(input())
if num%3==0 and num%5==0:
    print(f'{num} is fizzbuzz')
elif num%3==0:
    print(f'{num} is fizz')
elif num%5==0:
    print(f'{num} is buzz')
else:
    print(invalid)
# Out:
#  15
# 15 is fizzbuzz

# %%
# check weather the is +ve even -ve even +odd and -odd
num=int(input())
if num%2==0 and num>=0:
    print(f'{num} is +ve even')
elif num%2==0 and num<=0:
    print(f'{num} is -ve even')
elif num%2!=0 and num>=0:
    print(f'{num} is +ve odd')
elif num%2!=0 and num<=0:
    print(f'{num} is -ve odd')
else:
    print(invalid)
# Out:
#  5
# 5 is +ve odd

# %%
n=int(input())
#+ve even or not
if n>=0 and n%2==0:
    print(f'{n} +ve even')
elif n>=0:
    print(f'{n}+ve odd')
#-ve  even or odd 
elif n% 2==0:
    print(f'{n} -ve even')
else:
    print(f'{n} -ve odd')
# Out:
#  8
# 8 +ve even

# %%
#find the bigest number amonge the three num
num1=int(input())
num2=int(input())
num3=int(input())
if num1>num2 and num3:
    print(f'{num1} n1 is big')
elif num2>num1 and num3:
    print(f'{num2} n2 is big')
else:
    print(f'{num3} n3 is big')
# Out:
#  5
#  9
#  4
# 9 n2 is big

# %%
n1,n2,n3=map(int, input().split())
if n1>n2 and n1>n3:
    print(n1)
elif n2>n3:
    print(n2)
else:
    print(n3)
# Out:
#  1 2 3
# 3

# %%
#nestead if
num=int(input())
if num>0:
    if num%2==0:
        print(f'{num}+ve even')
    else:
        print(f'{num}+ve odd')
else:
    if num%2==0:
        print(f'{num}-ve even')
    else:
        print(f'{num}-ve odd')
# Out:
#  4
# 4+ve even

# %%
n1,n2,n3=map(int,input().split())
if n1>n2:
    if n1>n3:
        print(n1)
    else:
        print(n3)
else:
    if n2>n3:
        print(n2)
    else:
        print(n3)
