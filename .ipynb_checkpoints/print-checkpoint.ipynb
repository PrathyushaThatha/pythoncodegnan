# %%
# write a python program to display
name="Prathyusha"
age=21
city='Hyd'
career_goal='Become a python developer'
print("Name:",name)
print("Age:",age)
print("City:",city)
print("Career_goal:",career_goal)
# Out:
# Name: Prathyusha
# Age: 21
# City: Hyd
# Career_goal: Become a python developer

# %%
student='prathyusha'
college='vits'
branch='cse'
carrer='Developer'
print("Student Name:",student)
print("College Name:",college)
print("Branch:",branch)
print("Carrer goal:",carrer)
# Out:
# Student Name: prathyusha
# College Name: vits
# Branch: cse
# Carrer goal: Developer

# %%
p="9:00am:python"
a="11:
