# %%
# write a python code to accept students marks and display them
marks_subject1 = float(input('Enter the marks:'))
marks_subject2 = float(input('Enter the marks:'))
marks_subject3 = float(input('Enter the marks:'))
marks_subject4 = float(input('Enter the marks:'))
marks_subject5 = float(input('Enter the marks:'))
print('Subject 1:',marks_subject1)
print('Subject 2:',marks_subject2)
print('Subject 3:',marks_subject3)
print('Subject 4:',marks_subject4)
print('Subject 5:',marks_subject5)
Total = marks_subject1 + marks_subject2 + marks_subject3 + marks_subject4 + marks_subject5
avg = (Total/5)
print(Total)
print(avg)
# Out:
# Enter the marks: 20
# Enter the marks: 70
# Enter the marks: 58
# Enter the marks: 78
# Enter the marks: 39
# Subject 1: 20.0
# Subject 2: 70.0
# Subject 3: 58.0
# Subject 4: 78.0
# Subject 5: 39.0
# 265.0
# 53.0

# %%
#write a python program to accept birth year
# Write a program to accept birth year and calculate age
birth_year = int(input())
present = 2026
age = present - birth_year
print(age)
# Out:
#  2004
# 22

# %%
#area of triangle
l=int(input())
b=int(input())
a=l*b
print(a)
# Out:
#  3
#  5
# 15

# %%
#area of circle
pi=3.14
r=float(input())
area=pi*(r*r)
print("area of a circle:",area)
# Out:
#  4
# area of a circle: 50.24

# %%
#simple interest
principal=float(input())
rate=float(input())
time=float(input())
simple_interest=principal+rate+time/100
print(simple_interest)
