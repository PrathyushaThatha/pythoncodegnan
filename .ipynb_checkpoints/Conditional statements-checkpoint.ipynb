# %%
#problem
#check weather number is divisiable with 3 or not
num=int(input())
if num%3==0:
    print(f'{num} is divisiable by 3')
else:
    print(f'{num} is not divisible with3')
# Out:
#  6
# 6 is divisiable by 3

# %%
#check weather the number is divisiable with 3 5 or not
num=int(input())
if(num%3==0 and num%5==0):
    print(f'{num} is divisiable by both')
else:
    print(f'{num} is not divisiable by both')
# Out:
#  15
# 15 is divisiable by both

# %%
#1 check weather the number is even or not
num=int(input())
if(num%2==0):
    print(f'{num} is even')
else:
    print(f'{num} is odd')
# Out:
#  5
# 5 is odd

# %%
#2 check weather the number is divisiable with either 3 or 5
num=int(input())
if num%3==0 or num%5==0:
    print(f'{num} divisiable by either 3 or 5')
else:
        print(f'{num} not divisiable by either 3 or 5')
# Out:
#  7
# 7 not divisiable by either 3 or 5

# %%
#3 generate total bill if total bill more than 500 then 10% discount otherwise 0% discount
total_bill= int(input())
if total_bill>500:
    discount=total_bill*0.1
    print(f'total bill after 10% discount:{total_bill-discount}')
else:
    print(f'total bill after 0% discount:{total_bill}')
# Out:
#  501
# total bill after 10% discount:450.9

# %%
#4 
product=input()
stock=int(input())
if stock > 0:
    print(f" currently {product}:{stock} items available")
else:
    print(f' currently {product} out of stock')

# %%
#5in a shop contains some items along with prices like
products = {'pen' :5, 'book':20, 'pencil':3}
item=input().lower()
quantity=int(input())
if item in products:
    total_amount=products.get(item) * quantity
    print(f'total amount of {quantity}{item} is :{total_amount}')
else:
    print(f'{item} not available')
