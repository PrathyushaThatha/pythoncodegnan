# %%
import re

# %%
#match
string="The sky is blue and ocean is blue"
res=re.match("The",string)
print(res)
print(res.span())#it returns the matched pattern positions
print(res.group())#it returns the matched result
# Out:
# <re.Match object; span=(0, 3), match='The'>
# (0, 3)
# The

# %%
#match(pat,string ):It checks the weather the string is starts with pattern or not
try:
    string="The sky is blue and ocean is blue"
    res=re.match("sky",string)
    print(res)
    print(res.span())#it returns the matched pattern positions
    print(res.group())#it returns the matched result
except Exception as e:
    print("There is no Matched pattern")
# Out:
# None
# There is no Matched pattern

# %%
#search(pat,string):It checks the entire string and it returns the frist matched patterns
try:
    string="The sky is blue and ocean is blue"
    res=re.search("sky",string)
    print(res)
    print(res.span())#it returns the matched pattern positions
    print(res.group())#it returns the matched result
except Exception as e:
    print("There is no Matched pattern")
# Out:
# <re.Match object; span=(4, 7), match='sky'>
# (4, 7)
# sky

# %%
try:
    string="The sky is blue and ocean is blue"
    res=re.search("z",string)
    print(res)
    print(res.span())#it returns the matched pattern positions
    print(res.group())#it returns the matched result
except Exception as e:
    print("There is no Matched pattern")
# Out:
# None
# There is no Matched pattern

# %%
try:
    string="The sky is blue and ocean is blue"
    res=re.search("blue",string)
    print(res)
    print(res.span())#it returns the matched pattern positions
    print(res.group())#it returns the matched result
except Exception as e:
    print("There is no Matched pattern")
# Out:
# <re.Match object; span=(11, 15), match='blue'>
# (11, 15)
# blue

# %%
#findall(pat,string ):It returns the all macthed patterns as list
try:
    string="The sky is blue and ocean is blue"
    res=re.findall("[abco]",string)
    print(res)
except Exception as e:
    print("There is no Matched pattern")
# Out:
# ['b', 'a', 'o', 'c', 'a', 'b']

# %%
#split(pat,string):It splits the string wherever the pattern is matched
try:
    string="The sky is blue and ocean is blue"
    res=re.split("blue",string)
    print(res)
except Exception as e:
    print("There is no Matched pattern")
# Out:
# ['The sky is ', ' and ocean is ', '']

# %%
try:
    string="The sky is blue and ocean is blue"
    res=re.split("[abc]",string)
    print(res)
except Exception as e:
    print("There is no Matched pattern")
# Out:
# ['The sky is ', 'lue ', 'nd o', 'e', 'n is ', 'lue']

# %%
#sub(old_pat,new_pat,string):It sub string return old pattern in new pattern
try:
    string="The sky is blue and ocean is blue"
    res=re.sub("blue", "Red",string)
    print(res)
except Exception as e:
    print("There is no Matched pattern")
# Out:
# The sky is Red and ocean is Red

# %%
#findall(pat,string ):It returns the all macthed patterns as list
try:
    string="The sky is blue and ocean is blue"
    res=re.findall("[isabce]+",string)
    print(res)
except Exception as e:
    print("There is no Matched pattern")
# Out:
# ['e', 's', 'is', 'b', 'e', 'a', 'cea', 'is', 'b', 'e']

# %%
#findall(pat,string ):It returns the all macthed patterns as list
try:
    string="The sky is blue and ocean is bl9ue 2376"
    res=re.findall("[a-zA-z]+",string)
    print(res)
except Exception as e:
    print("There is no Matched pattern")
# Out:
# ['The', 'sky', 'is', 'blue', 'and', 'ocean', 'is', 'bl', 'ue']

# %%
#findall(pat,string ):It returns the all macthed patterns as list
try:
    string="The sky is blue 123 and ocean is bl9ue 2376"
    res=re.findall("[0-9]+",string)
    print(res)
except Exception as e:
    print("There is no Matched pattern")
# Out:
# ['123', '9', '2376']

# %%
#findall(pat,string ):It returns the all macthed patterns as list
try:
    string="The sky is blue and ocean is bl9ue 2376"
    res=re.findall("[0-9]*",string)
    print(res)
except Exception as e:
    print("There is no Matched pattern")
# Out:
# ['', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '9', '', '', '', '2376', '']

# %%
#findall(pat,string ):It returns the all macthed patterns as list
try:
    string="The sky is blue and ocean is bl9ue 2376"
    res=re.findall("[0-9]",string)
    print(res)
except Exception as e:
    print("There is no Matched pattern")
# Out:
# ['9', '2', '3', '7', '6']

# %%
#\D-except digit
try:
    string="The sky is blue and ocean is bl9ue 2376"
    res=re.findall(r"[\D]+",string)
    print(res)
except Exception as e:
    print("There is no Matched pattern")
# Out:
# ['The sky is blue and ocean is bl', 'ue ']

# %%
#validate mobile number
try:
    mobile = input()
    res = re.fullmatch("^[6-9][0-9]{9}",mobile)
    print(res)
    if res:
        print(f"{mobile} is valid")
    else:
        print(f"{mobile} is invalid")
except:
    print("There is no mathced pattern")
# Out:
#  7893247563
# <re.Match object; span=(0, 10), match='7893247563'>
# 7893247563 is valid

# %%
#validate mobile number
try:
    mobile = input()
    res = re.fullmatch("^[6-9][0-9]{9}",mobile)
    print(res)
    if res:
        print(f"{mobile} is valid")
    else:
        print(f"{mobile} is invalid")
except:
    print("There is no mathced pattern")
# Out:
#  5789365312
# None
# 5789365312 is invalid

# %%
#validate mobile number
try:
    mobile = input()
    res = re.fullmatch("^[6-9][0-9]{9}",mobile)
    print(res)
    if res:
        print(f"{mobile} is valid")
    else:
        print(f"{mobile} is invalid")
except:
    print("There is no mathced pattern")
# Out:
#  789324756a
# None
# 789324756a is invalid

# %%
#validate pan number
try:
    panno = input()
    res = re.fullmatch("^[A-Z]{5}[0-9]{4}[A-Z]{1}",panno)
    print(res)
    if res:
        print(f"{panno} is valid")
    else:
        print(f"{panno} is invalid")
except:
    print("There is no mathced pattern")
# Out:
#  ABCDE1234Z
# <re.Match object; span=(0, 10), match='ABCDE1234Z'>
# ABCDE1234Z is valid

# %%
#validate aadhar number
try:
    aadharno = input()
    res = re.fullmatch(r"^[2-9][0-9]{3}\s?[0-9]{4}\s?[0-9]{4}\s?",aadharno)
    print(res)
    if res:
        print(f"{aadhar} is valid")
    else:
        print(f"{aadhar} is invalid")
except:
    print("There is no mathced pattern")
# Out:
#  5252 1007 2294
# <re.Match object; span=(0, 14), match='5252 1007 2294'>
# There is no mathced pattern

# %%
#validate email
import re
try:
    email= input()
    res = re.fullmatch(r"^[a-z0-9][a-z0-9.]+\@[a-z0-9]+\.[a-z]{2,3}$",email)
    print(res)
    if res:
        print(f"{email} is valid")
    else:
        print(f"{email} is invalid")
except:
    print("There is no mathced pattern")
# Out:
#  prathyushathatha@gmail.com
# <re.Match object; span=(0, 26), match='prathyushathatha@gmail.com'>
# prathyushathatha@gmail.com is valid

# %%
# Date validate
import re
try:
    date= input()
    res = re.fullmatch(r"^(0?[1-9]|[12][0-9]|3[01])/(0?[1-9]|1[0-2])/(\d{4})",date)
    print(res)
    if res:
        print(f"{date} is valid")
    else:
        print(f"{date} is invalid")
except:
    print("There is no mathced pattern")
# Out:
#  13/09/2004
# <re.Match object; span=(0, 10), match='13/09/2004'>
# 13/09/2004 is valid

# %%
# Date validate
import re
try:
    date= input()
    res = re.fullmatch(r"^(0?[1-9]|[12][0-9]|3[01])[/-](0?[1-9]|1[0-2])[/-](\d{4})",date)
    print(res)
    if res:
        print(f"{date} is valid")
    else:
        print(f"{date} is invalid")
except:
    print("There is no mathced pattern")
# Out:
#  1/12-2005
# <re.Match object; span=(0, 9), match='1/12-2005'>
# 1/12-2005 is valid
