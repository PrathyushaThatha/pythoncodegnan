# %%
n=4
for i in range(n):
    for j in range(n):
        if j%2==0 and j+1:
            print(' 1',end=' ')
        else:
            print(' ', end=' ')
    print()
# Out:
#  1    1
#  1    1
#  1    1
#  1    1
