# %%
#Syntax Errors:
print("Hello')
# Out:
#   Cell In[3], line 2
#     print("Hello')
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
print("hello"
# Out:
#   Cell In[4], line 2
#
#     ^
# _IncompleteInputError: incomplete input

# %%
if(0==0):
print(0)
# Out:
#   Cell In[6], line 2
#     print(0)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
#runtime error
arr=[1,2,3,4,5]
print[arr[6]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 3
#       1 #runtime error
#       2 arr=[1,2,3,4,5]
# ----> 3 print[arr[6]]
#
# IndexError: list index out of range

# %%
g=("name:",'prathyusha',"age:",20)
print(g(gender))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 g=("name:",'prathyusha',"age:",20)
# ----> 2 print(g(gender))
#
# NameError: name 'gender' is not defined

# %%
#try block with exception
try:
    list=list[1,2,3]
    print(list[10])
    print("hi")
except:
    print("something wrong in try block")
else:
    print("no exception in raised in try block")
finally:
    print("program done")
# Out:
# something wrong in try block
# program done

# %%
#there is no exception in try block
try:
    list=[1,2,3]
    print(list[2])
    print("hi")
except:
    print("something wrong in try block")
else:
    print("no exception in raised in try block")
finally:
    print("program done")
# Out:
# 3
# hi
# no exception in raised in try block
# program done

# %%
#we cannot handling the syntax error
try:
    print("Hello')
except:
    print("something wrong in try block")
else:
    print("no exception in raised in try block")
finally:
    print("program done")
# Out:
#   Cell In[2], line 2
#     print("Hello')
#           ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
try:
    a=10
    b=0
    c=a/b
    print(c)
except Exception as e:
    print(f"something wrong in try block :{e}")
# Out:
# something wrong in try block :division by zero

# %%
#a=10
#b=a.append(0)
try:
    a=10
    b=a.append(0)
    print(b)
except Exception as e:
    print(f"something wrong in try block :{e}")
# Out:
# something wrong in try block :'int' object has no attribute 'append'

# %%
#AttributeError
try:
    a=10
    b=a.append(0)
    print(b)
except ZeroDivisionError as e:
    print(f"Zero division not possible:{e}")
except ValueError as e:
    print(f" Value error raised in try block :{e}")
#except Exception as e:
  #  print(f"something wrong in try block :{e}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 7
#       3     b=a.append(0)
#       4     print(b)
#       5 except ZeroDivisionError as e:
#       6     print(f"Zero division not possible:{e}")
# ----> 7 except ValueError as e:
#       8     print(f" Value error raised in try block :{e}")
#       9 #except Exception as e:
#      10   #  print(f"something wrong in try block :{e}")
#
# AttributeError: 'int' object has no attribute 'append'

# %%
try:
    a=10
    b=0
    c=a/b
    print(c)
except ZeroDivisionError as e:
    print(f"Zero division not possible:{e}")
except ValueError as e:
    print(f" Value error raised in try block :{e}")
except Exception as e:
    print(f"something wrong in try block :{e}")
# Out:
# Zero division not possible:division by zero

# %%
#It execute the specific exception block when specified exception raised otherwise,it excecute the common expect block
try:
    a=10
    b=
    c=a/b
    print(c)
except ZeroDivisionError as e:
    print(f"Zero division not possible:{e}")
except ValueError as e:
    print(f" Value error raised in try block :{e}")
except Exception as e:#common exception block with exception class
    print(f"something wrong in try block :{e}")
